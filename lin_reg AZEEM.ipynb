# %%
import pandas as pd
i,p

# %%
car= pd.read_csv('C:\\Users\\user\\Downloads\\car data.csv')

# %%
print(car.to_string())
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0                         ritz  2014           3.35          5.590       27000    Petrol      Dealer       Manual      0
# 1                          sx4  2013           4.75          9.540       43000    Diesel      Dealer       Manual      0
# 2                         ciaz  2017           7.25          9.850        6900    Petrol      Dealer       Manual      0
# 3                      wagon r  2011           2.85          4.150        5200    Petrol      Dealer       Manual      0
# 4                        swift  2014           4.60          6.870       42450    Diesel      Dealer       Manual      0
# 5                vitara brezza  2018           9.25          9.830        2071    Diesel      Dealer       Manual      0
# 6                         ciaz  2015           6.75          8.120       18796    Petrol      Dealer       Manual      0
# ...

# %%
car.head(100)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# ..            ...   ...            ...            ...         ...       ...
# 95  corolla altis  2012           5.85          18.61       72000    Petrol
# 96         innova  2016          20.75          25.39       29000    Diesel
# 97  corolla altis  2017          17.00          18.64        8700    Petrol
# 98  corolla altis  2013           7.05          18.61       45000    Petrol
# 99       fortuner  2010           9.65          20.45       50024    Diesel
#
#    Seller_Type Transmission  Owner
# ...

# %%
car['Seller_Type']=car['Seller_Type'].map({'Dealer':0, 'Individual':1})
car['Transmission']=car['Transmission'].map({'Manual':0, 'Automatic':1})

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# ...

# %%
Fuel = pd.get_dummies(car['Fuel_Type'], drop_first=True)
car= pd.concat([car, Fuel], axis=1)
del car['Fuel_Type']

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Seller_Type  \
# 0     ritz  2014           3.35           5.59       27000            0
# 1      sx4  2013           4.75           9.54       43000            0
# 2     ciaz  2017           7.25           9.85        6900            0
# 3  wagon r  2011           2.85           4.15        5200            0
# 4    swift  2014           4.60           6.87       42450            0
#
#    Transmission  Owner  Diesel  Petrol
# 0             0      0       0       1
# 1             0      0       1       0
# 2             0      0       0       1
# 3             0      0       0       1
# 4             0      0       1       0
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Seller_Type  \
# 0     ritz  2014           3.35           5.59       27000            0
# 1      sx4  2013           4.75           9.54       43000            0
# 2     ciaz  2017           7.25           9.85        6900            0
# ...

# %%
del car['Car_Name']
del car['Year']

# %%
import numpy

# %%
def scalling(x):
    return (x-numpy.mean(x))/numpy.std(x)

# %%
car = car.apply(scalling)

# %%
car.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Seller_Type  Transmission  \
# 0      -0.258416      -0.236215   -0.256224    -0.737285      -0.39148
# 1       0.017481       0.221505    0.155911    -0.737285      -0.39148
# 2       0.510154       0.257427   -0.773969    -0.737285      -0.39148
# 3      -0.356950      -0.403079   -0.817758    -0.737285      -0.39148
# 4      -0.012079      -0.087890    0.141743    -0.737285      -0.39148
#
#       Owner    Diesel    Petrol
# 0 -0.174501 -0.498962  0.509327
# 1 -0.174501  2.004162 -1.963374
# 2 -0.174501 -0.498962  0.509327
# 3 -0.174501 -0.498962  0.509327
# 4 -0.174501  2.004162 -1.963374
#    Selling_Price  Present_Price  Kms_Driven  Seller_Type  Transmission  \
# 0      -0.258416      -0.236215   -0.256224    -0.737285      -0.39148
# 1       0.017481       0.221505    0.155911    -0.737285      -0.39148
# 2       0.510154       0.257427   -0.773969    -0.737285      -0.39148
# ...

# %%
x = car.drop('Selling_Price',axis = 1)
y = car['Selling_Price']

# %%
from sklearn.model_selection import train_test_split as train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=80)

# %%
from sklearn import metrics

# %%
print("R2 Score: ", round(metrics.r2_score(y_test,y_pred),3))
print("MSE: ", round(metrics.mean_squared_error(y_test,y_pred),2))
print("RMSE: ", round(numpy.sqrt(metrics.mean_squared_error(y_test,y_pred)),2))
# Out:
# R2 Score:  -1.988
# MSE:  2.44
# RMSE:  1.56
# R2 Score:  -1.988
# MSE:  2.44
# RMSE:  1.56

# %%
from sklearn.linear_model import LinearRegression 
lin_reg_model = LinearRegression()
lin_reg_model.fit(x_train,y_train)
# Out:
# LinearRegression()
# LinearRegression()

# %%
training_data_prediction = lin_reg_model.predict(x_train)

# %%
prediction = lin_reg_model.predict(x_train)

# %%
from sklearn import metrics

# %%
train_error_score = metrics.r2_score(y_train, training_data_prediction) 
print("R squared Error - Training : ", train_error_score)
# Out:
# R squared Error - Training :  0.8501936360249505
# R squared Error - Training :  0.8501936360249505

# %%
y_pred = lin_reg_model.predict(x_test)

# %%
test_error_score = metrics.r2_score(y_test, y_pred) 
print("R squared Error - Test: ", test_error_score)
# Out:
# R squared Error - Test:  0.7245293815219757
# R squared Error - Test:  0.7245293815219757

# %%
import seaborn as cars

# %%
cars.regplot(y_test, y_pred, scatter_kws={"color": "green"}, line_kws={"color": "blue"})
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price'>
# <AxesSubplot:xlabel='Selling_Price'>
